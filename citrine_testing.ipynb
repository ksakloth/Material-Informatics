# %%
import numpy as np
import pandas as pd
from citrine import load_data,output_string_to_float,data_split,choose_model,setup_param_grid
from citrine import fit_ml_model,metrics_ml_model,avg_metric,overall_avg
from citrine import fit_mlp_nn,metrics_mlp_model,wrapper_nn
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Data exploration and preprocessing
# * **Data is split into features and multi-label target**
# * **Data is converted into the format fit for machine learning**

# %%
X,y = load_data('challenge_data/training_data.csv',['formulaA','formulaB'],'stabilityVec') #loading data, checking for NaN and returning X,Y

Y = output_string_to_float(y) #changing labels to usable format
# Out:
# Removing 0 nan rows
# Original dataset shape: (2572, 99)
# Features shape after dropping formulaA,formulaB and StabilityVector: (2572, 96)
# Target shape: (2572, 9)

# %% [markdown]
# ### Model training and validation
# * **Data is divided into train and test for each label**
# * **Features are oversampled and standaridized and each label is fit to the model**
# * **Hyperparameter tuning is done on the fly**
# * **The weighted precision, recall and f1-score is collected for each label's test set**
# * **The model average is also recorded**

# %% [markdown]
# ### Random Forest Classifier and respective metrics

# %%
v,w = choose_model('RandomForestClassifier') #takes RandomForestClassifier as a model and gives the  
#hyperparameters which can be tuned along with the datatype
parameters = setup_param_grid(v,[[10,20],['gini','entropy'],['auto','sqrt'],[5,10]]) #setting up the dictionary for 
#hyperparameter optimization
rf_metrics_df = metrics_ml_model(X,Y,'RandomForestClassifier',parameters,None) #stores metrics 
rf_metrics_df.to_csv('rf.csv',sep=',')  #passing dataframe to a csv file
# Out:
# There are 4 hyper parameters ['n_estimators', 'criterion', 'max_features', 'max_depth'] of type ['int', 'str', 'int', 'int'] respectively
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
precision = avg_metric(rf_metrics_df,'precision') #precision values weighted by the support for all 9 labels
print('The weighted precision for each label: '+str(precision))
overall_avg(precision,'precision') #average precision
recall = avg_metric(rf_metrics_df,'recall') #recall values weighted by the support for all 9 labels
print('The weighted recall for each label: '+str(recall))
overall_avg(recall,'recall') #average recall
f1 = avg_metric(rf_metrics_df,'f1-score')#f-1 scores weighted by the support for all 9 labels
print('The weighted f1-score for each label: '+str(f1))
overall_avg(f1,'f1-score')#average f1-score
# Out:
# The weighted precision for each label: [0.97, 0.97, 0.88, 0.94, 0.87, 0.93, 0.89, 0.87, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.96, 0.91, 0.84, 0.92, 0.83, 0.9, 0.83, 0.85, 0.96]
# The average recall is: 0.89
# The weighted f1-score for each label: [0.97, 0.93, 0.85, 0.92, 0.84, 0.91, 0.85, 0.86, 0.97]
# The average f1-score is: 0.90
# 0.9

# %% [markdown]
# ### Logistic Regression and respective metrics

# %%
v,w = choose_model('LogisticRegression') #takes Logistic regression as model and gives the hyper parameters which can be tuned
parameters = setup_param_grid(v,[['l1','l2'],[0.1,1],[True,False]]) #setting up the dictionary for hyper parameter optimization
lr_metrics_df = metrics_ml_model(X,Y,'LogisticRegression',parameters,None) #storing all the metrics in a dataframe
lr_metrics_df.to_csv('lr.csv',sep=',')  #passing dataframe to a csv file
# Out:
# There are 3 hyper parameters ['penalty', 'C', 'fit_intercept'] of type ['str', 'float', 'bool'] respectively
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
precision = avg_metric(lr_metrics_df,'precision') #precision values weighted by the support for all 9 labels
print('The weighted precision for each label: '+str(precision))
overall_avg(precision,'precision')  #average precision
recall = avg_metric(lr_metrics_df,'recall') #recall values weighted by the support for all 9 labels
print('The weighted recall for each label: '+str(recall))
overall_avg(recall,'recall') #average recall
f1 = avg_metric(lr_metrics_df,'f1-score')#f-1 scores weighted by the support for all 9 labels
print('The weighted f1-score for each label: '+str(f1))
overall_avg(f1,'f1-score')#average f1-score
# Out:
# The weighted precision for each label: [0.97, 0.97, 0.81, 0.93, 0.8, 0.91, 0.88, 0.86, 0.97]
# The average precision is: 0.90
# The weighted recall for each label: [0.94, 0.86, 0.73, 0.82, 0.72, 0.76, 0.69, 0.77, 0.94]
# The average recall is: 0.80
# The weighted f1-score for each label: [0.95, 0.91, 0.75, 0.86, 0.74, 0.82, 0.73, 0.79, 0.95]
# The average f1-score is: 0.83
# 0.83

# %% [markdown]
# ### Support Vector Machine and respective metrics

# %%
v,w = choose_model('SVC')  #takes SupportVectorMachine as model and gives the hyper parameters which can be tuned
parameters = setup_param_grid(v,[['rbf','linear'],[1,10],[None,'balanced']]) #setting up the dictionary for hyper parameter optimization
svm_metrics_df = metrics_ml_model(X,Y,'SVC',parameters,None) #storing all the metrics in a dataframe
svm_metrics_df.to_csv('svm.csv',sep=',') #passing dataframe to a csv file
# Out:
# There are 3 hyper parameters ['kernel', 'C', 'class_weight'] of type ['str', 'float', 'dict'] respectively
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=10, shrinking=True,
#   tol=0.001, verbose=False)

# %%
precisions = avg_metric(svm_metrics_df,'precision') #precision values weighted by the support for all 9 labels
overall_avg(precisions,'precision')  #average precision
recall = avg_metric(svm_metrics_df,'recall') #recall values weighted by the support for all 9 labels
overall_avg(recall,'recall') #average recall
f1 = avg_metric(svm_metrics_df,'f1-score') #f-1 scores weighted by the support for all 9 labels
overall_avg(f1,'f1-score') #average f1-score
# Out:
# The average precision is: 0.92
# The average recall is: 0.91
# The average f1-score is: 0.92
# 0.92

# %% [markdown]
# ### Multi-layer Perceptron (MLP) and respective metrics

# %%
v,w=choose_model('MLPClassifier')
parameters =setup_param_grid(v,[[256,512],['adam','RMSprop'],[0.5,0.3]])
df3 = wrapper_nn(parameters,X,Y)
# Out:
# There are 3 hyper parameters ['mlp_units', 'optimizer', 'dropout'] of type ['int', 'str', 'float'] respectively
# For params: ['adam', 0.5, 256]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00107: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00130: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00243: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00193: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00164: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00133: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00224: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00216: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00098: early stopping
# The metrics for ['adam', 0.5, 256]   f1-score  precision  recall  support
# 0      0.99       0.99    0.99      631
# 1      0.32       0.43    0.25       12
# 0      0.98       0.98    0.99      625
# 1      0.28       0.36    0.22       18
# 0      0.90       0.92    0.89      506
# 1      0.66       0.63    0.70      137
# 0      0.97       0.97    0.97      601
# 1      0.52       0.54    0.50       42
# 0      0.92       0.92    0.92      501
# 1      0.73       0.73    0.73      142
# 0      0.97       0.96    0.98      598
# 1      0.52       0.60    0.47       45
# 0      0.93       0.93    0.94      557
# 1      0.53       0.55    0.51       86
# 0      0.93       0.92    0.94      537
# 1      0.63       0.65    0.60      106
# 0      0.99       0.98    1.00      622
# 1      0.56       0.82    0.43       21
# The weighted precision for each label: [0.98, 0.96, 0.86, 0.94, 0.88, 0.93, 0.88, 0.88, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.98, 0.97, 0.85, 0.94, 0.88, 0.94, 0.88, 0.88, 0.98]
# The average recall is: 0.92
# The weighted f1-score for each label: [0.98, 0.96, 0.85, 0.94, 0.88, 0.94, 0.88, 0.88, 0.98]
# The average f1-score is: 0.92
# For params: ['adam', 0.5, 512]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00101: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00127: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00252: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00129: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00264: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00126: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00192: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00175: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00117: early stopping
# The metrics for ['adam', 0.5, 512]   f1-score  precision  recall  support
# 0      0.99       0.98    0.99      631
# 1      0.20       0.25    0.17       12
# 0      0.98       0.98    0.98      625
# 1      0.29       0.29    0.28       18
# 0      0.91       0.91    0.90      506
# 1      0.66       0.65    0.66      137
# 0      0.96       0.97    0.96      601
# 1      0.52       0.49    0.55       42
# 0      0.93       0.93    0.92      501
# 1      0.74       0.73    0.74      142
# 0      0.96       0.97    0.96      598
# 1      0.55       0.51    0.60       45
# 0      0.94       0.93    0.94      557
# 1      0.56       0.59    0.52       86
# 0      0.93       0.93    0.94      537
# 1      0.66       0.67    0.65      106
# 0      0.99       0.98    1.00      622
# 1      0.55       0.75    0.43       21
# The weighted precision for each label: [0.97, 0.96, 0.85, 0.94, 0.89, 0.94, 0.88, 0.89, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.97, 0.96, 0.85, 0.93, 0.88, 0.93, 0.88, 0.89, 0.98]
# The average recall is: 0.92
# The weighted f1-score for each label: [0.98, 0.96, 0.86, 0.93, 0.89, 0.93, 0.89, 0.89, 0.98]
# The average f1-score is: 0.92
# For params: ['adam', 0.3, 256]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00128: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00103: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00252: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00099: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00220: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00206: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00168: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00167: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00173: early stopping
# The metrics for ['adam', 0.3, 256]   f1-score  precision  recall  support
# 0      0.98       0.98    0.98      631
# 1      0.17       0.17    0.17       12
# 0      0.98       0.98    0.98      625
# 1      0.25       0.29    0.22       18
# 0      0.92       0.93    0.91      506
# 1      0.70       0.68    0.73      137
# 0      0.96       0.97    0.95      601
# 1      0.48       0.43    0.55       42
# 0      0.93       0.93    0.93      501
# 1      0.76       0.75    0.76      142
# 0      0.96       0.97    0.96      598
# 1      0.54       0.53    0.56       45
# 0      0.94       0.92    0.95      557
# 1      0.54       0.59    0.49       86
# 0      0.92       0.92    0.93      537
# 1      0.61       0.62    0.59      106
# 0      0.99       0.98    0.99      622
# 1      0.48       0.67    0.38       21
# The weighted precision for each label: [0.96, 0.96, 0.88, 0.93, 0.89, 0.94, 0.88, 0.87, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.96, 0.96, 0.87, 0.92, 0.89, 0.93, 0.89, 0.87, 0.97]
# The average recall is: 0.92
# The weighted f1-score for each label: [0.96, 0.96, 0.87, 0.93, 0.89, 0.93, 0.89, 0.87, 0.97]
# The average f1-score is: 0.92
# For params: ['adam', 0.3, 512]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00104: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00086: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00119: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00114: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00109: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00169: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00174: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00118: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00077: early stopping
# The metrics for ['adam', 0.3, 512]   f1-score  precision  recall  support
# 0      0.99       0.99    0.99      631
# 1      0.27       0.30    0.25       12
# 0      0.98       0.98    0.98      625
# 1      0.29       0.29    0.28       18
# 0      0.91       0.91    0.91      506
# 1      0.66       0.66    0.66      137
# 0      0.96       0.98    0.95      601
# 1      0.55       0.47    0.67       42
# 0      0.93       0.93    0.93      501
# 1      0.76       0.75    0.76      142
# 0      0.96       0.97    0.95      598
# 1      0.50       0.45    0.58       45
# 0      0.94       0.93    0.95      557
# 1      0.55       0.60    0.51       86
# 0      0.93       0.93    0.93      537
# 1      0.63       0.64    0.62      106
# 0      0.99       0.98    0.99      622
# 1      0.54       0.62    0.48       21
# The weighted precision for each label: [0.98, 0.96, 0.86, 0.95, 0.89, 0.93, 0.89, 0.88, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.98, 0.96, 0.86, 0.93, 0.89, 0.92, 0.89, 0.88, 0.97]
# The average recall is: 0.92
# The weighted f1-score for each label: [0.98, 0.96, 0.86, 0.93, 0.89, 0.93, 0.89, 0.88, 0.98]
# The average f1-score is: 0.92
# For params: ['RMSprop', 0.5, 256]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00088: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00132: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00194: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00180: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00260: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00146: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00158: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00226: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00070: early stopping
# The metrics for ['RMSprop', 0.5, 256]   f1-score  precision  recall  support
# 0      0.98       0.98    0.99      631
# 1      0.17       0.18    0.17       12
# 0      0.98       0.98    0.98      625
# 1      0.29       0.29    0.28       18
# 0      0.90       0.94    0.86      506
# 1      0.69       0.60    0.81      137
# 0      0.96       0.97    0.95      601
# 1      0.47       0.41    0.55       42
# 0      0.93       0.94    0.91      501
# 1      0.75       0.72    0.78      142
# 0      0.96       0.96    0.96      598
# 1      0.52       0.51    0.53       45
# 0      0.93       0.94    0.92      557
# 1      0.59       0.56    0.64       86
# 0      0.94       0.93    0.94      537
# 1      0.67       0.68    0.67      106
# 0      0.98       0.98    0.99      622
# 1      0.54       0.55    0.52       21
# The weighted precision for each label: [0.97, 0.96, 0.87, 0.93, 0.89, 0.93, 0.89, 0.89, 0.97]
# The average precision is: 0.92
# The weighted recall for each label: [0.97, 0.96, 0.85, 0.92, 0.88, 0.93, 0.88, 0.9, 0.97]
# The average recall is: 0.92
# The weighted f1-score for each label: [0.96, 0.96, 0.86, 0.93, 0.89, 0.93, 0.88, 0.9, 0.97]
# The average f1-score is: 0.92
# For params: ['RMSprop', 0.5, 512]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00063: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00093: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00188: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00107: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00202: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00196: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00127: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00163: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00077: early stopping
# The metrics for ['RMSprop', 0.5, 512]   f1-score  precision  recall  support
# 0      0.98       0.99    0.98      631
# 1      0.24       0.23    0.25       12
# 0      0.97       0.99    0.96      625
# 1      0.35       0.26    0.50       18
# 0      0.90       0.92    0.88      506
# 1      0.67       0.62    0.72      137
# 0      0.96       0.98    0.94      601
# 1      0.53       0.44    0.67       42
# 0      0.93       0.94    0.92      501
# 1      0.78       0.75    0.80      142
# 0      0.95       0.97    0.93      598
# 1      0.45       0.38    0.56       45
# 0      0.94       0.95    0.93      557
# 1      0.62       0.59    0.65       86
# 0      0.93       0.94    0.91      537
# 1      0.66       0.62    0.71      106
# 0      0.98       0.98    0.97      622
# 1      0.45       0.39    0.52       21
# The weighted precision for each label: [0.98, 0.97, 0.86, 0.94, 0.9, 0.93, 0.9, 0.89, 0.96]
# The average precision is: 0.93
# The weighted recall for each label: [0.97, 0.95, 0.85, 0.92, 0.89, 0.9, 0.89, 0.88, 0.96]
# The average recall is: 0.91
# The weighted f1-score for each label: [0.97, 0.95, 0.85, 0.93, 0.9, 0.92, 0.9, 0.89, 0.96]
# The average f1-score is: 0.92
# For params: ['RMSprop', 0.3, 256]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00064: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00081: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00159: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00173: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00159: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00176: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00200: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00127: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00059: early stopping
# The metrics for ['RMSprop', 0.3, 256]   f1-score  precision  recall  support
# 0      0.99       0.99    0.99      631
# 1      0.25       0.25    0.25       12
# 0      0.98       0.98    0.97      625
# 1      0.32       0.27    0.39       18
# 0      0.90       0.93    0.87      506
# 1      0.67       0.61    0.75      137
# 0      0.96       0.97    0.94      601
# 1      0.50       0.43    0.62       42
# 0      0.92       0.94    0.90      501
# 1      0.75       0.70    0.80      142
# 0      0.95       0.97    0.94      598
# 1      0.48       0.42    0.56       45
# 0      0.93       0.94    0.91      557
# 1      0.58       0.53    0.64       86
# 0      0.93       0.94    0.91      537
# 1      0.67       0.62    0.73      106
# 0      0.98       0.98    0.98      622
# 1      0.50       0.48    0.52       21
# The weighted precision for each label: [0.98, 0.96, 0.86, 0.93, 0.89, 0.93, 0.89, 0.89, 0.96]
# The average precision is: 0.92
# The weighted recall for each label: [0.98, 0.95, 0.84, 0.92, 0.88, 0.91, 0.87, 0.88, 0.96]
# The average recall is: 0.91
# The weighted f1-score for each label: [0.98, 0.96, 0.85, 0.93, 0.88, 0.92, 0.88, 0.89, 0.96]
# The average f1-score is: 0.92
# For params: ['RMSprop', 0.3, 512]
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00086: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00098: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00200: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00123: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00168: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00159: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00114: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00104: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00228: early stopping
# The metrics for ['RMSprop', 0.3, 512]   f1-score  precision  recall  support
# 0      0.98       0.99    0.98      631
# 1      0.24       0.23    0.25       12
# 0      0.97       0.99    0.95      625
# 1      0.32       0.24    0.50       18
# 0      0.90       0.92    0.88      506
# 1      0.66       0.61    0.71      137
# 0      0.95       0.97    0.93      601
# 1      0.46       0.37    0.60       42
# 0      0.92       0.94    0.90      501
# 1      0.74       0.69    0.81      142
# 0      0.96       0.96    0.95      598
# 1      0.48       0.43    0.53       45
# 0      0.93       0.94    0.93      557
# 1      0.57       0.56    0.58       86
# 0      0.92       0.94    0.90      537
# 1      0.63       0.57    0.71      106
# 0      0.97       0.98    0.96      622
# 1      0.39       0.31    0.52       21
# The weighted precision for each label: [0.98, 0.97, 0.85, 0.93, 0.88, 0.92, 0.89, 0.88, 0.96]
# The average precision is: 0.92
# The weighted recall for each label: [0.97, 0.94, 0.84, 0.91, 0.88, 0.92, 0.88, 0.87, 0.95]
# The average recall is: 0.91
# The weighted f1-score for each label: [0.97, 0.95, 0.85, 0.92, 0.88, 0.93, 0.88, 0.87, 0.95]
# The average f1-score is: 0.91

# %%
X1 = load_data('challenge_data/test_data.csv',['formulaA','formulaB'],None)#loading the held-out test set
# Out:
# Removing 0 nan rows
# Original dataset shape: (749, 99)
# Features shape after dropping formulaA and formulaB: (749, 97)

# %%
x,y,z = df3[['f1-score','recall','precision']].idxmax() 
if x==y==z:
    print('The optimum parameters as chosen from f1-score,recall and precision are '+str(df3['optimizer'][x])+','+str(df3['dropout'][x])+' dropout,'+str(df3['neurons'][x])+' neurons')
    mlp_metrics_df,predicted_array = metrics_mlp_model(parameters,X,Y,df3['optimizer'][x],df3['dropout'][x],df3['neurons'][x],X1)#storing all metrics in a dataframe
elif x==y or x==z:
    print('The optimum parameters as chosen from f1-score and either one metric are '+str(df3['optimizer'][x])+','+str(df3['dropout'][x])+' dropout,'+str(df3['neurons'][x])+' neurons')
    mlp_metrics_df,predicted_array = metrics_mlp_model(parameters,X,Y,df3['optimizer'][x],df3['dropout'][x],df3['neurons'][x],X1)#storing all metrics in a dataframe
else:
    print('The optimum parameters as chosen from f1-score are '+str(df3['optimizer'][x])+','+str(df3['dropout'][x])+' dropout,'+str(df3['neurons'][x])+' neurons')
    mlp_metrics_df,predicted_array = metrics_mlp_model(parameters,X,Y,df3['optimizer'][x],df3['dropout'][x],df3['neurons'][x],X1)#storing all metrics in a dataframe
# Out:
# The optimum parameters as chosen from f1-score and either one metric are adam,0.5 dropout,256 neurons
# Label: 0
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3782, 96)
# Resampled y_train shape: (3782,)
# Epoch 00123: early stopping
# Label: 1
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3718, 96)
# Resampled y_train shape: (3718,)
# Epoch 00151: early stopping
# Label: 2
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2936, 96)
# Resampled y_train shape: (2936,)
# Epoch 00217: early stopping
# Label: 3
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3590, 96)
# Resampled y_train shape: (3590,)
# Epoch 00267: early stopping
# Label: 4
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (2974, 96)
# Resampled y_train shape: (2974,)
# Epoch 00203: early stopping
# Label: 5
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3578, 96)
# Resampled y_train shape: (3578,)
# Epoch 00199: early stopping
# Label: 6
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3310, 96)
# Resampled y_train shape: (3310,)
# Epoch 00274: early stopping
# Label: 7
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3286, 96)
# Resampled y_train shape: (3286,)
# Epoch 00204: early stopping
# Label: 8
# 25% Data split into test set
# X_train shape: (1929, 96)
# y_train shape: (1929,)
# X_test shape: (643, 96)
# y_test shape: (643,)
# Resampled X_train shape: (3780, 96)
# Resampled y_train shape: (3780,)
# Epoch 00128: early stopping

# %%
mlp_metrics_df.to_csv('mlp.csv',sep=',') #passing dataframe to a csv file
precision = avg_metric(mlp_metrics_df,'precision') #precision values weighted by the support for all 9 labels
overall_avg(precision,'precision')  #average precision
recall = avg_metric(mlp_metrics_df,'recall') #recall values weighted by the support for all 9 labels
overall_avg(recall,'recall') #average recall
f1 = avg_metric(mlp_metrics_df,'f1-score') #f-1 scores weighted by the support for all 9 labels
overall_avg(f1,'f1-score') #average f1-score
# Out:
# The average precision is: 0.92
# The average recall is: 0.92
# The average f1-score is: 0.92
# 0.92

# %% [markdown]
# ### Predicting on the held out test_data.csv
# * **Since the MLP has the highest precision,recall and f1-score, it has been used as the model to predict on the test_data.csv**
# * **The predicted values can be found in the test_data_with_vec.csv file attached in the zip folder**

# %%
predicted_arr = np.array(predicted_array).reshape(X1.shape[0],Y.shape[1])
np.savetxt("y_predicted_nn.csv", predicted_arr, delimiter=",")
pd.read_csv('y_predicted_nn.csv',sep=',',names=['label1','label2','label3','label4','label5','label6','label7','label8','label9'])
